# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import seaborn as sns
import shutil

# %%
# Read CSV from dataset
diagnosis = pd.read_csv('CoronaHack-Respiratory-Sound-Dataset/Corona-Hack-Respiratory-Sound-Metadata.csv', encoding='cp1252')
diagnosis.head()
# Out:
#                         USER_ID COUNTRY  AGE COVID_STATUS ENGLISH_PROFICIENCY  \
# 0  vK2bLRNzllXNeyOMudnNSL5cfpG2   India   24      healthy                   Y
# 1  bjA2KpSxneNskrLBeqi4bqoTDQl2   India   72      healthy                   Y
# 2  FSzobvJqOXf0rI6X05cHqOiU9Mu2   India   54      healthy                   Y
# 3  EqDWckxbsETyHUeBLQ8jLtxlhir2   India   31      healthy                   Y
# 4  FGRDO4IBbAejR0WHD5YbkXTCasg2   India   26      healthy                   Y
#
#   GENDER COUNTY_RO_STATE CITY_LOCALITY  Diabetes  Asthma  ...     DATES  \
# 0      M       Karnataka     Bangalore         0       0  ...  20200413
# 1      M     Maharashtra         Thane         0       0  ...  20200413
# 2      M     Maharashtra    Thane West         0       0  ...  20200413
# 3      M       Karnataka     Bangalore         0       0  ...  20200413
# 4      M         Haryana       gurgaon         0       0  ...  20200413
#
#                                       breathing-deep  \
# ...

# %%
#read d
cough_heavy = [x for x in diagnosis['cough-heavy'] if pd.isnull(x) == False]
cough_shallow = [x for x in diagnosis['cough-shallow'] if pd.isnull(x) == False]
counting_fast = [x for x in diagnosis['counting-fast'] if pd.isnull(x) == False]
counting_normal = [x for x in diagnosis['counting-normal'] if pd.isnull(x) == False]
vowel_a = [x for x in diagnosis['vowel-a'] if pd.isnull(x) == False]
vowel_e = [x for x in diagnosis['vowel-e'] if pd.isnull(x) == False]
vowel_o = [x for x in diagnosis['vowel-o'] if pd.isnull(x) == False]

# %%
#create a directory for the result of this process
os.mkdir('dataset')
os.mkdir('dataset/cough_heavy')
os.mkdir('dataset/cough_shallow')
os.mkdir('dataset/talk')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-9-2ac1d8c545d6> in <module>
# ----> 1 os.mkdir('dataset')
#       2 os.mkdir('dataset/cough_heavy')
#       3 os.mkdir('dataset/cough_shallow')
#       4 os.mkdir('dataset/talk')
#
# FileExistsError: [Errno 17] File exists: 'dataset'

# %%
a = 0
for f in cough_heavy:
    original = 'CoronaHack-Respiratory-Sound-Dataset'+f
    target = 'dataset/cough_heavy/cough-heavy-'+str(a)+'.wav'
    shutil.copyfile(original, target)
    print(target)
    a = a+1
# Out:
# dataset/cough_heavy/cough-heavy-0.wav
# dataset/cough_heavy/cough-heavy-1.wav
# dataset/cough_heavy/cough-heavy-2.wav
# dataset/cough_heavy/cough-heavy-3.wav
# dataset/cough_heavy/cough-heavy-4.wav
# dataset/cough_heavy/cough-heavy-5.wav
# dataset/cough_heavy/cough-heavy-6.wav
# dataset/cough_heavy/cough-heavy-7.wav
# dataset/cough_heavy/cough-heavy-8.wav
# dataset/cough_heavy/cough-heavy-9.wav
# dataset/cough_heavy/cough-heavy-10.wav
# dataset/cough_heavy/cough-heavy-11.wav
# dataset/cough_heavy/cough-heavy-12.wav
# dataset/cough_heavy/cough-heavy-13.wav
# dataset/cough_heavy/cough-heavy-14.wav
# dataset/cough_heavy/cough-heavy-15.wav
# dataset/cough_heavy/cough-heavy-16.wav
# dataset/cough_heavy/cough-heavy-17.wav
# dataset/cough_heavy/cough-heavy-18.wav
# dataset/cough_heavy/cough-heavy-19.wav
# dataset/cough_heavy/cough-heavy-20.wav
# dataset/cough_heavy/cough-heavy-21.wav
# dataset/cough_heavy/cough-heavy-22.wav
# dataset/cough_heavy/cough-heavy-23.wav
# ...

# %%
a = 0
for f in cough_shallow:
    original = 'CoronaHack-Respiratory-Sound-Dataset'+f
    target = 'dataset/cough_shallow/cough-shallow-'+str(a)+'.wav'
    shutil.copyfile(original, target)
    print(target)
    a = a+1
# Out:
# dataset/cough_shallow/cough-shallow-0.wav
# dataset/cough_shallow/cough-shallow-1.wav
# dataset/cough_shallow/cough-shallow-2.wav
# dataset/cough_shallow/cough-shallow-3.wav
# dataset/cough_shallow/cough-shallow-4.wav
# dataset/cough_shallow/cough-shallow-5.wav
# dataset/cough_shallow/cough-shallow-6.wav
# dataset/cough_shallow/cough-shallow-7.wav
# dataset/cough_shallow/cough-shallow-8.wav
# dataset/cough_shallow/cough-shallow-9.wav
# dataset/cough_shallow/cough-shallow-10.wav
# dataset/cough_shallow/cough-shallow-11.wav
# dataset/cough_shallow/cough-shallow-12.wav
# dataset/cough_shallow/cough-shallow-13.wav
# dataset/cough_shallow/cough-shallow-14.wav
# dataset/cough_shallow/cough-shallow-15.wav
# dataset/cough_shallow/cough-shallow-16.wav
# dataset/cough_shallow/cough-shallow-17.wav
# dataset/cough_shallow/cough-shallow-18.wav
# dataset/cough_shallow/cough-shallow-19.wav
# dataset/cough_shallow/cough-shallow-20.wav
# dataset/cough_shallow/cough-shallow-21.wav
# ...

# %%
a = 0
for f in counting_normal:
    original = 'CoronaHack-Respiratory-Sound-Dataset'+f
    target = 'dataset/talk/counting-normal-'+str(a)+'.wav'
    shutil.copyfile(original, target)
    print(target)
    a = a+1
# Out:
# dataset/talk/counting-normal-0.wav
# dataset/talk/counting-normal-1.wav
# dataset/talk/counting-normal-2.wav
# dataset/talk/counting-normal-3.wav
# dataset/talk/counting-normal-4.wav
# dataset/talk/counting-normal-5.wav
# dataset/talk/counting-normal-6.wav
# dataset/talk/counting-normal-7.wav
# dataset/talk/counting-normal-8.wav
# dataset/talk/counting-normal-9.wav
# dataset/talk/counting-normal-10.wav
# dataset/talk/counting-normal-11.wav
# dataset/talk/counting-normal-12.wav
# dataset/talk/counting-normal-13.wav
# dataset/talk/counting-normal-14.wav
# dataset/talk/counting-normal-15.wav
# dataset/talk/counting-normal-16.wav
# dataset/talk/counting-normal-17.wav
# dataset/talk/counting-normal-18.wav
# dataset/talk/counting-normal-19.wav
# dataset/talk/counting-normal-20.wav
# dataset/talk/counting-normal-21.wav
# dataset/talk/counting-normal-22.wav
# dataset/talk/counting-normal-23.wav
# dataset/talk/counting-normal-24.wav
# dataset/talk/counting-normal-25.wav
# ...

# %%
a = 0
for f in counting_fast:
    original = 'CoronaHack-Respiratory-Sound-Dataset'+f
    target = 'dataset/talk/counting-fast-'+str(a)+'.wav'
    shutil.copyfile(original, target)
    print(target)
    a = a+1
# Out:
# dataset/talk/counting-fast-0.wav
# dataset/talk/counting-fast-1.wav
# dataset/talk/counting-fast-2.wav
# dataset/talk/counting-fast-3.wav
# dataset/talk/counting-fast-4.wav
# dataset/talk/counting-fast-5.wav
# dataset/talk/counting-fast-6.wav
# dataset/talk/counting-fast-7.wav
# dataset/talk/counting-fast-8.wav
# dataset/talk/counting-fast-9.wav
# dataset/talk/counting-fast-10.wav
# dataset/talk/counting-fast-11.wav
# dataset/talk/counting-fast-12.wav
# dataset/talk/counting-fast-13.wav
# dataset/talk/counting-fast-14.wav
# dataset/talk/counting-fast-15.wav
# dataset/talk/counting-fast-16.wav
# dataset/talk/counting-fast-17.wav
# dataset/talk/counting-fast-18.wav
# dataset/talk/counting-fast-19.wav
# dataset/talk/counting-fast-20.wav
# dataset/talk/counting-fast-21.wav
# dataset/talk/counting-fast-22.wav
# dataset/talk/counting-fast-23.wav
# dataset/talk/counting-fast-24.wav
# dataset/talk/counting-fast-25.wav
# dataset/talk/counting-fast-26.wav
# dataset/talk/counting-fast-27.wav
# ...

# %%
a = 0
for f in vowel_a:
    original = 'CoronaHack-Respiratory-Sound-Dataset'+f
    target = 'dataset/talk/vowel-a-'+str(a)+'.wav'
    shutil.copyfile(original, target)
    print(target)
    a = a+1
# Out:
# dataset/talk/vowel-a-0.wav
# dataset/talk/vowel-a-1.wav
# dataset/talk/vowel-a-2.wav
# dataset/talk/vowel-a-3.wav
# dataset/talk/vowel-a-4.wav
# dataset/talk/vowel-a-5.wav
# dataset/talk/vowel-a-6.wav
# dataset/talk/vowel-a-7.wav
# dataset/talk/vowel-a-8.wav
# dataset/talk/vowel-a-9.wav
# dataset/talk/vowel-a-10.wav
# dataset/talk/vowel-a-11.wav
# dataset/talk/vowel-a-12.wav
# dataset/talk/vowel-a-13.wav
# dataset/talk/vowel-a-14.wav
# dataset/talk/vowel-a-15.wav
# dataset/talk/vowel-a-16.wav
# dataset/talk/vowel-a-17.wav
# dataset/talk/vowel-a-18.wav
# dataset/talk/vowel-a-19.wav
# dataset/talk/vowel-a-20.wav
# dataset/talk/vowel-a-21.wav
# dataset/talk/vowel-a-22.wav
# dataset/talk/vowel-a-23.wav
# dataset/talk/vowel-a-24.wav
# dataset/talk/vowel-a-25.wav
# dataset/talk/vowel-a-26.wav
# dataset/talk/vowel-a-27.wav
# dataset/talk/vowel-a-28.wav
# dataset/talk/vowel-a-29.wav
# dataset/talk/vowel-a-30.wav
# dataset/talk/vowel-a-31.wav
# dataset/talk/vowel-a-32.wav
# ...

# %%
a = 0
for f in vowel_o:
    original = 'CoronaHack-Respiratory-Sound-Dataset'+f
    target = 'dataset/talk/vowel-o-'+str(a)+'.wav'
    shutil.copyfile(original, target)
    print(target)
    a = a+1
# Out:
# dataset/talk/vowel-o-0.wav
# dataset/talk/vowel-o-1.wav
# dataset/talk/vowel-o-2.wav
# dataset/talk/vowel-o-3.wav
# dataset/talk/vowel-o-4.wav
# dataset/talk/vowel-o-5.wav
# dataset/talk/vowel-o-6.wav
# dataset/talk/vowel-o-7.wav
# dataset/talk/vowel-o-8.wav
# dataset/talk/vowel-o-9.wav
# dataset/talk/vowel-o-10.wav
# dataset/talk/vowel-o-11.wav
# dataset/talk/vowel-o-12.wav
# dataset/talk/vowel-o-13.wav
# dataset/talk/vowel-o-14.wav
# dataset/talk/vowel-o-15.wav
# dataset/talk/vowel-o-16.wav
# dataset/talk/vowel-o-17.wav
# dataset/talk/vowel-o-18.wav
# dataset/talk/vowel-o-19.wav
# dataset/talk/vowel-o-20.wav
# dataset/talk/vowel-o-21.wav
# dataset/talk/vowel-o-22.wav
# dataset/talk/vowel-o-23.wav
# dataset/talk/vowel-o-24.wav
# dataset/talk/vowel-o-25.wav
# dataset/talk/vowel-o-26.wav
# dataset/talk/vowel-o-27.wav
# dataset/talk/vowel-o-28.wav
# dataset/talk/vowel-o-29.wav
# dataset/talk/vowel-o-30.wav
# dataset/talk/vowel-o-31.wav
# dataset/talk/vowel-o-32.wav
# ...

# %%
a = 0
for f in vowel_e:
    original = 'CoronaHack-Respiratory-Sound-Dataset'+f
    target = 'dataset/talk/vowel-e-'+str(a)+'.wav'
    shutil.copyfile(original, target)
    print(target)
    a = a+1
# Out:
# dataset/talk/vowel-e-0.wav
# dataset/talk/vowel-e-1.wav
# dataset/talk/vowel-e-2.wav
# dataset/talk/vowel-e-3.wav
# dataset/talk/vowel-e-4.wav
# dataset/talk/vowel-e-5.wav
# dataset/talk/vowel-e-6.wav
# dataset/talk/vowel-e-7.wav
# dataset/talk/vowel-e-8.wav
# dataset/talk/vowel-e-9.wav
# dataset/talk/vowel-e-10.wav
# dataset/talk/vowel-e-11.wav
# dataset/talk/vowel-e-12.wav
# dataset/talk/vowel-e-13.wav
# dataset/talk/vowel-e-14.wav
# dataset/talk/vowel-e-15.wav
# dataset/talk/vowel-e-16.wav
# dataset/talk/vowel-e-17.wav
# dataset/talk/vowel-e-18.wav
# dataset/talk/vowel-e-19.wav
# dataset/talk/vowel-e-20.wav
# dataset/talk/vowel-e-21.wav
# dataset/talk/vowel-e-22.wav
# dataset/talk/vowel-e-23.wav
# dataset/talk/vowel-e-24.wav
# dataset/talk/vowel-e-25.wav
# dataset/talk/vowel-e-26.wav
# dataset/talk/vowel-e-27.wav
# dataset/talk/vowel-e-28.wav
# dataset/talk/vowel-e-29.wav
# dataset/talk/vowel-e-30.wav
# dataset/talk/vowel-e-31.wav
# dataset/talk/vowel-e-32.wav
# ...
